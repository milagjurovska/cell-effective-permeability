# %%
from gcn_model import train, predict

# %%
import shutil
shutil.rmtree("processed", ignore_errors=True)

# %%
best_model = train(
    csv_path="caco2_processed.csv",
    target_col="target",
    use_graph=True,
    epochs=50,
    batch_size=64,
    lr=1e-3
)

print("Best checkpoint:", best_model)

results = predict(
    csv_path="caco2_processed.csv",
    checkpoint=best_model,
    out_csv="preds.csv"
)

print(results.head())
# Out:
# Processing...
# Done!
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_model = train(
#       2     csv_path="caco2_processed.csv",
#       3     target_col="target",
#       4     use_graph=True,
#       5     epochs=50,
#       6     batch_size=64,
#       7     lr=1e-3
#       8 )
#      10 print("Best checkpoint:", best_model)
#      12 results = predict(
#      13     csv_path="caco2_processed.csv",
#      14     checkpoint=best_model,
#      15     out_csv="preds.csv"
#      16 )
#
# File ~\PycharmProjects\MANU\gcn_model.py:191, in train(csv_path, target_col, use_graph, epochs, batch_size, lr, weight_decay, val_split, device, save_dir)
#     187 def train(csv_path: str, target_col: str = 'target', use_graph: bool = True,
#     188           epochs: int = 100, batch_size: int = 64, lr: float = 1e-3, weight_decay: float = 1e-5,
# ...
