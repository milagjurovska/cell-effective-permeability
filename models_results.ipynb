# %%
from gcn_model import train, predict

# %%
import shutil
shutil.rmtree("processed", ignore_errors=True)

# %%
best_model = train(
    csv_path="caco2_processed.csv",
    target_col="target",
    use_graph=True,
    epochs=50,
    batch_size=64,
    lr=1e-3
)

print("Best checkpoint:", best_model)

results = predict(
    csv_path="caco2_processed.csv",
    checkpoint=best_model,
    out_csv="preds.csv"
)

print(results.head())
# Out:
# Processing...
# Done!
# Epoch 001 | train_loss=13.3473 | val_mae=3.4407 val_rmse=3.5341 val_r2=-20.0408
# Epoch 002 | train_loss=7.8988 | val_mae=1.6403 val_rmse=2.1969 val_r2=-7.1305
# Epoch 003 | train_loss=4.2855 | val_mae=1.6089 val_rmse=2.1671 val_r2=-6.9120
# Epoch 004 | train_loss=2.5969 | val_mae=1.0833 val_rmse=1.4376 val_r2=-2.4815
# Epoch 005 | train_loss=1.3317 | val_mae=0.6614 val_rmse=0.8785 val_r2=-0.3003
# Epoch 006 | train_loss=0.5896 | val_mae=0.5033 val_rmse=0.6438 val_r2=0.3018
# Epoch 007 | train_loss=0.4505 | val_mae=0.6545 val_rmse=0.8261 val_r2=-0.1496
# Epoch 008 | train_loss=0.6504 | val_mae=0.4961 val_rmse=0.6264 val_r2=0.3390
# Epoch 009 | train_loss=0.3818 | val_mae=0.4475 val_rmse=0.5557 val_r2=0.4798
# Epoch 010 | train_loss=0.6131 | val_mae=0.4586 val_rmse=0.5629 val_r2=0.4662
# Epoch 011 | train_loss=0.5861 | val_mae=0.7274 val_rmse=0.8754 val_r2=-0.2911
# Epoch 012 | train_loss=0.6649 | val_mae=0.5523 val_rmse=0.6687 val_r2=0.2467
# Epoch 013 | train_loss=0.5563 | val_mae=0.6471 val_rmse=0.7918 val_r2=-0.0561
# Epoch 014 | train_loss=0.4652 | val_mae=0.4537 val_rmse=0.5728 val_r2=0.4472
# Epoch 015 | train_loss=0.3336 | val_mae=0.4259 val_rmse=0.5325 val_r2=0.5224
# Epoch 016 | train_loss=0.5739 | val_mae=0.5095 val_rmse=0.6353 val_r2=0.3200
# Epoch 017 | train_loss=0.5791 | val_mae=0.5862 val_rmse=0.7068 val_r2=0.1585
# Epoch 018 | train_loss=0.6081 | val_mae=0.5191 val_rmse=0.6518 val_r2=0.2843
# Epoch 019 | train_loss=0.5225 | val_mae=0.5196 val_rmse=0.6302 val_r2=0.3309
# Epoch 020 | train_loss=0.5639 | val_mae=0.5698 val_rmse=0.7120 val_r2=0.1459
# Epoch 021 | train_loss=0.5385 | val_mae=0.5508 val_rmse=0.6632 val_r2=0.2590
# Epoch 022 | train_loss=0.5755 | val_mae=0.5014 val_rmse=0.6337 val_r2=0.3236
# Epoch 023 | train_loss=0.5543 | val_mae=0.5586 val_rmse=0.6733 val_r2=0.2363
# Epoch 024 | train_loss=0.5701 | val_mae=0.4969 val_rmse=0.6272 val_r2=0.3374
# Epoch 025 | train_loss=0.5601 | val_mae=0.5437 val_rmse=0.6549 val_r2=0.2775
# Epoch 026 | train_loss=0.5445 | val_mae=0.5152 val_rmse=0.6480 val_r2=0.2925
# Epoch 027 | train_loss=0.5346 | val_mae=0.5584 val_rmse=0.6737 val_r2=0.2354
# Epoch 028 | train_loss=0.5689 | val_mae=0.5066 val_rmse=0.6391 val_r2=0.3120
# Epoch 029 | train_loss=0.4966 | val_mae=0.5663 val_rmse=0.6823 val_r2=0.2157
# Epoch 030 | train_loss=0.5796 | val_mae=0.4092 val_rmse=0.5015 val_r2=0.5764
# Epoch 031 | train_loss=0.3034 | val_mae=0.8179 val_rmse=0.9704 val_r2=-0.5863
# Epoch 032 | train_loss=1.2697 | val_mae=1.4070 val_rmse=1.5076 val_r2=-2.8292
# Epoch 033 | train_loss=1.8549 | val_mae=1.0534 val_rmse=1.1889 val_r2=-1.3812
# Epoch 034 | train_loss=0.8956 | val_mae=0.5292 val_rmse=0.6753 val_r2=0.2316
# Epoch 035 | train_loss=0.7121 | val_mae=0.5587 val_rmse=0.6773 val_r2=0.2271
# Epoch 036 | train_loss=0.5542 | val_mae=0.5617 val_rmse=0.7066 val_r2=0.1589
# Epoch 037 | train_loss=0.3769 | val_mae=0.4341 val_rmse=0.5385 val_r2=0.5115
# Epoch 038 | train_loss=0.3937 | val_mae=0.4209 val_rmse=0.5198 val_r2=0.5448
# Epoch 039 | train_loss=0.5550 | val_mae=0.4204 val_rmse=0.5247 val_r2=0.5363
# Epoch 040 | train_loss=0.4063 | val_mae=0.9003 val_rmse=1.0513 val_r2=-0.8618
# Epoch 041 | train_loss=0.5149 | val_mae=0.4124 val_rmse=0.5061 val_r2=0.5686
# Epoch 042 | train_loss=0.8569 | val_mae=0.5598 val_rmse=0.6993 val_r2=0.1762
# Epoch 043 | train_loss=0.3947 | val_mae=0.6377 val_rmse=0.7611 val_r2=0.0242
# Epoch 044 | train_loss=0.5248 | val_mae=0.4170 val_rmse=0.5112 val_r2=0.5598
# Epoch 045 | train_loss=0.3402 | val_mae=0.6454 val_rmse=0.7726 val_r2=-0.0057
# Epoch 046 | train_loss=0.5851 | val_mae=1.0125 val_rmse=1.2626 val_r2=-1.6858
# Epoch 047 | train_loss=0.9112 | val_mae=0.4791 val_rmse=0.5921 val_r2=0.4094
# Epoch 048 | train_loss=0.7172 | val_mae=0.7221 val_rmse=0.8639 val_r2=-0.2574
# Epoch 049 | train_loss=0.8408 | val_mae=0.5700 val_rmse=0.7086 val_r2=0.1540
# Epoch 050 | train_loss=0.3472 | val_mae=0.4114 val_rmse=0.5074 val_r2=0.5663
# Early stopping
# Best model saved to runs\best_gcn.pt
# Best checkpoint: runs\best_gcn.pt
# Saved predictions to preds.csv
#                                               smiles    target  mol_weight  \
# 0            Oc1cc(O)c2c(c1)OC(c1ccc(O)c(O)c1)C(O)C2 -6.220000     290.271
# 1                   C/C=C\C#CCC/C=C\C=C\C(=O)NCC(C)C -3.860000     245.366
# 2  COc1ccc2c3c1O[C@H]1[C@@H](O)C=C[C@H]4[C@@H](C2... -4.090000     299.370
# 3                                     CN1CC(=O)NC1=N -5.935409     113.120
# 4  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=Cc5oncc5C[C@]4(... -4.840000     337.463
#
#       logP  num_atoms  num_bonds  num_rotatable_bonds  num_h_donors  \
# 0  1.54610         21         23                    1             5
# 1  3.23070         18         17                    6             1
# 2  1.50110         22         26                    1             1
# 3 -1.01723          8          8                    0             2
# 4  4.22100         25         29                    0             1
#
#    num_h_acceptors  prediction
# 0                6   -5.583420
# 1                1   -4.475502
# 2                4   -4.769032
# 3                2   -5.185047
# 4                3   -4.595592
